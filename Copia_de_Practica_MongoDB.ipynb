# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenesticesi/ExtraccionData/blob/main/Copia_de_Practica_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="green">*Para iniciar, cree su propia copia de este notebook. File> Save a Copy in Drive*</font>

# %% [markdown]
# #Práctica de MongoDB utilizando pymongo

# %% [markdown]
# A continuación se encuentran las instrucciones para instalar pymongo en notebook en Colab, la configuración de la conexión a un cluster montado en Atlas MongoDB con el fin de realizar consultas en la base de datos test.
#
# **Instrucciones**
#
# Realice cada una de las instrucciones, analice el resultado y realice las consultas propuestas al final.

# %% [markdown]
# ##1. Objetivo
#
# El objetivo de este taller es poder realizar consultas a una base de datos MongoDB montada en Atlas, utilizando pymongo

# %% [markdown]
# ##2. Configuración pymongo

# %% [markdown]
# Pymongo es una librería de Python para poder conectarnos a una base de datos MongoDB. En este ejemplo vamos a ver cómo conectarnos desde Python a MongoDB.

# %%
# !python --version
# Out:
# Python 3.12.11

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 33.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 16.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.1

# %%
import pymongo

# %% [markdown]
# ##3. Configurando la conexión a la base de datos test en el cluster en Atlas MongoDB

# %%
# Trying 3.6+ connection string
client = pymongo.MongoClient(
    "mongodb+srv://ead:ead12345@cluster0.v5rih5b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client.ead
collection = db.users

# %%
db
# Out:
# Database(MongoClient(host=['ac-vv4a0mx-shard-00-00.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-02.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-01.v5rih5b.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-mrr86e-shard-0', tls=True), 'ead')

# %% [markdown]
# ##Inserción de un documento
#
# Modifique la siguiente instrucción, antes de ejecutarla.  Coloque sus propios datos antes de realizar la inserción del documento.

# %%
#modifique los datos antes de insertar el documento

db.users.insert_one({'nombre':'Ruben Dario','apellido':'Sabogal Urbano','edad':60, 'genero':'masculino'})
# Out:
# InsertOneResult(ObjectId('68d58c21872b0599fc341a63'), acknowledged=True)

# %% [markdown]
# ##Consultas

# %% [markdown]
# Consultar todos los documentos en la colección *users*

# %%
list(db.users.find())
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'),
#   'nombre': 'Andres',
#   'apellido': 'Rodriguez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66c69e743756af26287fb69f'),
#   'nombre': 'Felipe',
#   'apellido': 'Perez'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'),
#   'nombre': 'Danna',
#   'apellido': 'Espinosa',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'),
#   'nombre': 'Jonathan',
#   'apellido': 'Pacheco',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'),
#   'nombre': 'David',
#   'apellido': 'Orozco',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d0f279b65667b4a5a498bc'),
#   'nombre': 'Alexandra',
#   'apellido': 'Arenas',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d3320c4e581d85d3624d2b'),
#   'nombre': 'Danny',
#   'apellido': 'Martinez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d93c1976cc429b75215303'),
#   'nombre': 'Carlos Alberto',
#   'apellido': 'Martinez Ramirez',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215304'),
#   'nombre': 'Maria Antonieta',
#   'apellido': 'De las Nieves',
#   'edad': 37,
#   'genero': 'Femenino'},
#  {'_id': ObjectId('66d93c2876cc429b75215305'),
#   'nombre': 'Ramón',
#   'apellido': 'Villagra',
#   'edad': 65,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215306'),
#   'nombre': 'Michael',
#   'apellido': 'Jackson',
#   'edad': 52,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66df57c44e564b16d03c8297'),
#   'nombre': 'Cristian David',
#   'apellido': 'Gonzalez',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e879ef7a1ca99f58b89424'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e87d477a1ca99f58b89426'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e90fe34cdf64a3f86b9631'),
#   'nombre': 'William ',
#   'apellido': 'Cañas',
#   'edad': 56,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66ea3e41d717140caee638da'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ea3fdc57a45de96889a9d7'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66eca5e4486fb3df625689a9'),
#   'nombre': 'Albeto',
#   'apellido': 'Giraldo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecc79b18fce9c9574d4ce0'),
#   'nombre': 'Alberto',
#   'Giraldo': 'Caicedo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecf7279885b254cad9ecf5'),
#   'nombre': 'Andres',
#   'apellido': 'Borrero',
#   'edad': 27,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ed62ce8ad24b7c88fb5eb9'),
#   'nombre': 'Alejandro',
#   'apellido': 'Patiño',
#   'edad': 40,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb741c48c1d4299d20f8'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eee1995986e7f02ec94af7'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f0931a50efbcf41a5136b2')},
#  {'_id': ObjectId('66f0b9a6a744512cc0a45daf'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f231784638df56c36a4151'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f23ba3f759e5d8a95cd01c'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f83a9b808f0957a483ada8'),
#   'nombre': 'Yesid',
#   'apellido': 'Castelblanco',
#   'edad': 35,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67d1e227cbb3a2825b2bdb67'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 43,
#   'estatura': 1.6},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb68'),
#   'nombre': 'Luis',
#   'apellido': 'Ruiz',
#   'edad': 48,
#   'estatura': '1.70'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb69'),
#   'nombre': 'Leonor',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb6a'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67db4005cdce94eb28048f13')},
#  {'_id': ObjectId('67db40c4cdce94eb28048f15')},
#  {'_id': ObjectId('67db4239cdce94eb28048f1a'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db426dcdce94eb28048f1b'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 'treinta y tres',
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db5025cef8af8508084a3e'),
#   'nombre': 'Ricardo',
#   'apellido': 'Chicangana',
#   'edad': 44,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e020fcf9ac118b7ebeb9ba'),
#   'nombre': 'Fabian',
#   'apellido': 'Ortiz',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e03ba5a7fe6c5cbaa78c87'),
#   'nombre': 'Laura',
#   'apellido': 'Chaparro',
#   'edad': 24,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e406cf06601db2266ef129'),
#   'nombre': 'Ivan',
#   'apellido': 'Mora',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5ddd4f2df8b9d1485408a'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5deb4f2df8b9d1485408b'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e806a64c7ac3f94970398e'),
#   'nombre': 'sebastian',
#   'apellido': 'bonilla',
#   'edad': 30,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e980c1262e6b8bc6cd7c34'),
#   'nombre': 'Josué',
#   'apellido': 'Cobaleda',
#   'edad': 31,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9bc55b78b2d7303ca75dc'),
#   'nombre': 'Jhonattan Reales',
#   'apellido': 'Reales',
#   'edad': 26,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9e8f6b1aa8f907d316010'),
#   'nombre': 'Juan',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67fdc82cc5881dce4b10f52f'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67fdc84ec5881dce4b10f530'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado Angulo',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d1783e02f974d8ff0918ed'),
#   'nombre': 'Deibi',
#   'apellido': 'Bastidas',
#   'edad': 43,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d2d16dfe299cff65aefb01'),
#   'nombre': 'Darwin',
#   'apellido': 'Lenis',
#   'edad': 21,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d3e081d6bc5259fd2712ce'),
#   'nombre': 'Diana',
#   'apellido': 'López',
#   'edad': 23,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d42ee248396e781fd2f2e6'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42ef848396e781fd2f2e7'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f5e48396e781fd2f2e8'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f7048396e781fd2f2e9'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4626b3a5685ae5c2475b2'),
#   'nombre': 'William Alberto',
#   'apellido': 'Suaza Losada',
#   'edad': 42,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('68d46a0ce8dc84be6f7d17ed'),
#   'nombre': 'Yenny',
#   'apellido': 'Villarreal',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d486f1a3667c7041432055'),
#   'nombre': 'Carlos',
#   'apellido': 'Cepeda',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4916d4ed299576c35f9c7'),
#   'nombre': 'Yeny1',
#   'apellido': 'Villarreal2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492aa4ed299576c35f9ca'),
#   'nombre': 'Neny',
#   'apellido': 'cita',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492db4ed299576c35f9cb'),
#   'nombre': 'alexandra',
#   'apellido': 'suaza',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d494f04ed299576c35f9cd'),
#   'nombre': 'alexandra2',
#   'apellido': 'suaza2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d495f685a9ccca1468d68f'),
#   'nombre': 'Yenny3',
#   'apellido': 'Villarreal3',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d498614ed299576c35f9d0'),
#   'nombre': 'cristian',
#   'apellido': 'yepes',
#   'edad': 38,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d498954ed299576c35f9d1'),
#   'nombre': 'Cris',
#   'apellido': 'Yes',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4a101a9a01c1b4bcebea6'),
#   'nombre': 'Juanse',
#   'apellido': 'Orozco',
#   'edad': 35,
#   'estatura': 1.78},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d52b2777e8775ae8576fbc'),
#   'nombre': 'Carlos',
#   'apellido': 'García',
#   'edad': '35',
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d58c21872b0599fc341a63'),
#   'nombre': 'Ruben Dario',
#   'apellido': 'Sabogal Urbano',
#   'edad': 60,
#   'genero': 'masculino'}]

# %% [markdown]
# **Selección**
# Consultar los usuarios con edad igual a 28.

# %%
list(db.users.find({'edad':28}))
# Out:
# [{'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'}]

# %%
list(db.users.find({'edad':28}))
# Out:
# [{'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'}]

# %% [markdown]
# **Consultar un solo documento**

# %%
db.users.find_one()
# Out:
# {'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#  'nombre': 'Monica',
#  'apellido': 'Rojas',
#  'edad': 47,
#  'genero': 'femenino'}

# %% [markdown]
# **Proyección**
#
# Consultar los apellidos de todos los usuarios

# %%
list(db.users.find({},{'apellido':1}))
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'), 'apellido': 'Rodriguez'},
#  {'_id': ObjectId('66c69e743756af26287fb69f'), 'apellido': 'Perez'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'), 'apellido': 'Espinosa'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'), 'apellido': 'Pacheco'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'), 'apellido': 'Orozco'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66d0f279b65667b4a5a498bc'), 'apellido': 'Arenas'},
#  {'_id': ObjectId('66d3320c4e581d85d3624d2b'), 'apellido': 'Martinez'},
#  {'_id': ObjectId('66d93c1976cc429b75215303'), 'apellido': 'Martinez Ramirez'},
#  {'_id': ObjectId('66d93c2876cc429b75215304'), 'apellido': 'De las Nieves'},
#  {'_id': ObjectId('66d93c2876cc429b75215305'), 'apellido': 'Villagra'},
#  {'_id': ObjectId('66d93c2876cc429b75215306'), 'apellido': 'Jackson'},
#  {'_id': ObjectId('66df57c44e564b16d03c8297'), 'apellido': 'Gonzalez'},
#  {'_id': ObjectId('66e879ef7a1ca99f58b89424'), 'apellido': 'Murillas'},
#  {'_id': ObjectId('66e87d477a1ca99f58b89426'), 'apellido': 'Murillas'},
#  {'_id': ObjectId('66e90fe34cdf64a3f86b9631'), 'apellido': 'Cañas'},
#  {'_id': ObjectId('66ea3e41d717140caee638da'), 'apellido': 'Velez'},
#  {'_id': ObjectId('66ea3fdc57a45de96889a9d7'), 'apellido': 'Velez'},
#  {'_id': ObjectId('66eca5e4486fb3df625689a9'), 'apellido': 'Giraldo'},
#  {'_id': ObjectId('66ecc79b18fce9c9574d4ce0')},
#  {'_id': ObjectId('66ecf7279885b254cad9ecf5'), 'apellido': 'Borrero'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66ed62ce8ad24b7c88fb5eb9'), 'apellido': 'Patiño'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66eedb741c48c1d4299d20f8'), 'apellido': 'Triana'},
#  {'_id': ObjectId('66eee1995986e7f02ec94af7'), 'apellido': 'Triana'},
#  {'_id': ObjectId('66f0931a50efbcf41a5136b2')},
#  {'_id': ObjectId('66f0b9a6a744512cc0a45daf'), 'apellido': 'Estrada'},
#  {'_id': ObjectId('66f231784638df56c36a4151'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66f23ba3f759e5d8a95cd01c'), 'apellido': 'Estrada'},
#  {'_id': ObjectId('66f83a9b808f0957a483ada8'), 'apellido': 'Castelblanco'},
#  {'_id': ObjectId('67d1e227cbb3a2825b2bdb67'), 'apellido': 'Andrade'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb68'), 'apellido': 'Ruiz'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb69'), 'apellido': 'Restrepo'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb6a'), 'apellido': 'Jurado'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67db4005cdce94eb28048f13')},
#  {'_id': ObjectId('67db40c4cdce94eb28048f15')},
#  {'_id': ObjectId('67db4239cdce94eb28048f1a'), 'apellido': 'Meneses'},
#  {'_id': ObjectId('67db426dcdce94eb28048f1b'), 'apellido': 'Meneses'},
#  {'_id': ObjectId('67db5025cef8af8508084a3e'), 'apellido': 'Chicangana'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e020fcf9ac118b7ebeb9ba'), 'apellido': 'Ortiz'},
#  {'_id': ObjectId('67e03ba5a7fe6c5cbaa78c87'), 'apellido': 'Chaparro'},
#  {'_id': ObjectId('67e406cf06601db2266ef129'), 'apellido': 'Mora'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e5ddd4f2df8b9d1485408a'), 'apellido': 'Vergara'},
#  {'_id': ObjectId('67e5deb4f2df8b9d1485408b'), 'apellido': 'Vergara'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e806a64c7ac3f94970398e'), 'apellido': 'bonilla'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e980c1262e6b8bc6cd7c34'), 'apellido': 'Cobaleda'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e9bc55b78b2d7303ca75dc'), 'apellido': 'Reales'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e9e8f6b1aa8f907d316010'), 'apellido': 'Hurtado'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67fdc82cc5881dce4b10f52f'), 'apellido': 'Hurtado'},
#  {'_id': ObjectId('67fdc84ec5881dce4b10f530'), 'apellido': 'Hurtado Angulo'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d1783e02f974d8ff0918ed'), 'apellido': 'Bastidas'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d2d16dfe299cff65aefb01'), 'apellido': 'Lenis'},
#  {'_id': ObjectId('68d3e081d6bc5259fd2712ce'), 'apellido': 'López'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d42ee248396e781fd2f2e6'), 'apellido': 'Jaeger'},
#  {'_id': ObjectId('68d42ef848396e781fd2f2e7'), 'apellido': 'Jaeger'},
#  {'_id': ObjectId('68d42f5e48396e781fd2f2e8'), 'apellido': 'Jaeger'},
#  {'_id': ObjectId('68d42f7048396e781fd2f2e9'), 'apellido': 'Jaeger'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d4626b3a5685ae5c2475b2'), 'apellido': 'Suaza Losada'},
#  {'_id': ObjectId('68d46a0ce8dc84be6f7d17ed'), 'apellido': 'Villarreal'},
#  {'_id': ObjectId('68d486f1a3667c7041432055'), 'apellido': 'Cepeda'},
#  {'_id': ObjectId('68d4916d4ed299576c35f9c7'), 'apellido': 'Villarreal2'},
#  {'_id': ObjectId('68d492aa4ed299576c35f9ca'), 'apellido': 'cita'},
#  {'_id': ObjectId('68d492db4ed299576c35f9cb'), 'apellido': 'suaza'},
#  {'_id': ObjectId('68d494f04ed299576c35f9cd'), 'apellido': 'suaza2'},
#  {'_id': ObjectId('68d495f685a9ccca1468d68f'), 'apellido': 'Villarreal3'},
#  {'_id': ObjectId('68d498614ed299576c35f9d0'), 'apellido': 'yepes'},
#  {'_id': ObjectId('68d498954ed299576c35f9d1'), 'apellido': 'Yes'},
#  {'_id': ObjectId('68d4a101a9a01c1b4bcebea6'), 'apellido': 'Orozco'},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d52b2777e8775ae8576fbc'), 'apellido': 'García'},
#  {'_id': ObjectId('68d58c21872b0599fc341a63'), 'apellido': 'Sabogal Urbano'}]

# %% [markdown]
# **Proyección y selección**
#
# Consultar los usuarios nombre Monica y mostrar el apellido

# %%
list(db.users.find({'nombre':'Monica'},{'apellido':1}))
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('66f231784638df56c36a4151'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'), 'apellido': 'Rojas'}]

# %% [markdown]
# **Operadores**
#
# Consulte todos los operadores en [Operators MongoDB](https://www.mongodb.com/docs/manual/reference/operator/query/)

# %% [markdown]
# **Diferente**
#
# Mostrar los usuarios con nombre diferente a Mario

# %%
#se crea una variable usuario para recibir el resultado de la consulta
usuario = db.users.find({'nombre':{'$ne':'Mario'}})

# %%
#se muestra
list(usuario)
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'),
#   'nombre': 'Andres',
#   'apellido': 'Rodriguez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66c69e743756af26287fb69f'),
#   'nombre': 'Felipe',
#   'apellido': 'Perez'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'),
#   'nombre': 'Danna',
#   'apellido': 'Espinosa',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'),
#   'nombre': 'Jonathan',
#   'apellido': 'Pacheco',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'),
#   'nombre': 'David',
#   'apellido': 'Orozco',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d0f279b65667b4a5a498bc'),
#   'nombre': 'Alexandra',
#   'apellido': 'Arenas',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d3320c4e581d85d3624d2b'),
#   'nombre': 'Danny',
#   'apellido': 'Martinez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d93c1976cc429b75215303'),
#   'nombre': 'Carlos Alberto',
#   'apellido': 'Martinez Ramirez',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215304'),
#   'nombre': 'Maria Antonieta',
#   'apellido': 'De las Nieves',
#   'edad': 37,
#   'genero': 'Femenino'},
#  {'_id': ObjectId('66d93c2876cc429b75215305'),
#   'nombre': 'Ramón',
#   'apellido': 'Villagra',
#   'edad': 65,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215306'),
#   'nombre': 'Michael',
#   'apellido': 'Jackson',
#   'edad': 52,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66df57c44e564b16d03c8297'),
#   'nombre': 'Cristian David',
#   'apellido': 'Gonzalez',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e879ef7a1ca99f58b89424'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e87d477a1ca99f58b89426'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e90fe34cdf64a3f86b9631'),
#   'nombre': 'William ',
#   'apellido': 'Cañas',
#   'edad': 56,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66ea3e41d717140caee638da'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ea3fdc57a45de96889a9d7'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66eca5e4486fb3df625689a9'),
#   'nombre': 'Albeto',
#   'apellido': 'Giraldo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecc79b18fce9c9574d4ce0'),
#   'nombre': 'Alberto',
#   'Giraldo': 'Caicedo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecf7279885b254cad9ecf5'),
#   'nombre': 'Andres',
#   'apellido': 'Borrero',
#   'edad': 27,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ed62ce8ad24b7c88fb5eb9'),
#   'nombre': 'Alejandro',
#   'apellido': 'Patiño',
#   'edad': 40,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb741c48c1d4299d20f8'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eee1995986e7f02ec94af7'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f0931a50efbcf41a5136b2')},
#  {'_id': ObjectId('66f0b9a6a744512cc0a45daf'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f231784638df56c36a4151'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f23ba3f759e5d8a95cd01c'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f83a9b808f0957a483ada8'),
#   'nombre': 'Yesid',
#   'apellido': 'Castelblanco',
#   'edad': 35,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67d1e227cbb3a2825b2bdb67'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 43,
#   'estatura': 1.6},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb68'),
#   'nombre': 'Luis',
#   'apellido': 'Ruiz',
#   'edad': 48,
#   'estatura': '1.70'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb69'),
#   'nombre': 'Leonor',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb6a'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67db4005cdce94eb28048f13')},
#  {'_id': ObjectId('67db40c4cdce94eb28048f15')},
#  {'_id': ObjectId('67db4239cdce94eb28048f1a'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db426dcdce94eb28048f1b'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 'treinta y tres',
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db5025cef8af8508084a3e'),
#   'nombre': 'Ricardo',
#   'apellido': 'Chicangana',
#   'edad': 44,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e020fcf9ac118b7ebeb9ba'),
#   'nombre': 'Fabian',
#   'apellido': 'Ortiz',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e03ba5a7fe6c5cbaa78c87'),
#   'nombre': 'Laura',
#   'apellido': 'Chaparro',
#   'edad': 24,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e406cf06601db2266ef129'),
#   'nombre': 'Ivan',
#   'apellido': 'Mora',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5ddd4f2df8b9d1485408a'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5deb4f2df8b9d1485408b'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e806a64c7ac3f94970398e'),
#   'nombre': 'sebastian',
#   'apellido': 'bonilla',
#   'edad': 30,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e980c1262e6b8bc6cd7c34'),
#   'nombre': 'Josué',
#   'apellido': 'Cobaleda',
#   'edad': 31,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9bc55b78b2d7303ca75dc'),
#   'nombre': 'Jhonattan Reales',
#   'apellido': 'Reales',
#   'edad': 26,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9e8f6b1aa8f907d316010'),
#   'nombre': 'Juan',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67fdc82cc5881dce4b10f52f'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67fdc84ec5881dce4b10f530'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado Angulo',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d1783e02f974d8ff0918ed'),
#   'nombre': 'Deibi',
#   'apellido': 'Bastidas',
#   'edad': 43,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d2d16dfe299cff65aefb01'),
#   'nombre': 'Darwin',
#   'apellido': 'Lenis',
#   'edad': 21,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d3e081d6bc5259fd2712ce'),
#   'nombre': 'Diana',
#   'apellido': 'López',
#   'edad': 23,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d42ee248396e781fd2f2e6'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42ef848396e781fd2f2e7'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f5e48396e781fd2f2e8'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f7048396e781fd2f2e9'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4626b3a5685ae5c2475b2'),
#   'nombre': 'William Alberto',
#   'apellido': 'Suaza Losada',
#   'edad': 42,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('68d46a0ce8dc84be6f7d17ed'),
#   'nombre': 'Yenny',
#   'apellido': 'Villarreal',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d486f1a3667c7041432055'),
#   'nombre': 'Carlos',
#   'apellido': 'Cepeda',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4916d4ed299576c35f9c7'),
#   'nombre': 'Yeny1',
#   'apellido': 'Villarreal2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492aa4ed299576c35f9ca'),
#   'nombre': 'Neny',
#   'apellido': 'cita',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492db4ed299576c35f9cb'),
#   'nombre': 'alexandra',
#   'apellido': 'suaza',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d494f04ed299576c35f9cd'),
#   'nombre': 'alexandra2',
#   'apellido': 'suaza2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d495f685a9ccca1468d68f'),
#   'nombre': 'Yenny3',
#   'apellido': 'Villarreal3',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d498614ed299576c35f9d0'),
#   'nombre': 'cristian',
#   'apellido': 'yepes',
#   'edad': 38,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d498954ed299576c35f9d1'),
#   'nombre': 'Cris',
#   'apellido': 'Yes',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4a101a9a01c1b4bcebea6'),
#   'nombre': 'Juanse',
#   'apellido': 'Orozco',
#   'edad': 35,
#   'estatura': 1.78},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d52b2777e8775ae8576fbc'),
#   'nombre': 'Carlos',
#   'apellido': 'García',
#   'edad': '35',
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d58c21872b0599fc341a63'),
#   'nombre': 'Ruben Dario',
#   'apellido': 'Sabogal Urbano',
#   'edad': 60,
#   'genero': 'masculino'}]

# %% [markdown]
# **Usuarios con edad mayor a 20**

# %%
list(db.users.find({'edad':{'$gte':20}}))
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'),
#   'nombre': 'Andres',
#   'apellido': 'Rodriguez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'),
#   'nombre': 'Danna',
#   'apellido': 'Espinosa',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'),
#   'nombre': 'Jonathan',
#   'apellido': 'Pacheco',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'),
#   'nombre': 'David',
#   'apellido': 'Orozco',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d0f279b65667b4a5a498bc'),
#   'nombre': 'Alexandra',
#   'apellido': 'Arenas',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d3320c4e581d85d3624d2b'),
#   'nombre': 'Danny',
#   'apellido': 'Martinez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d93c1976cc429b75215303'),
#   'nombre': 'Carlos Alberto',
#   'apellido': 'Martinez Ramirez',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215304'),
#   'nombre': 'Maria Antonieta',
#   'apellido': 'De las Nieves',
#   'edad': 37,
#   'genero': 'Femenino'},
#  {'_id': ObjectId('66d93c2876cc429b75215305'),
#   'nombre': 'Ramón',
#   'apellido': 'Villagra',
#   'edad': 65,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215306'),
#   'nombre': 'Michael',
#   'apellido': 'Jackson',
#   'edad': 52,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66df57c44e564b16d03c8297'),
#   'nombre': 'Cristian David',
#   'apellido': 'Gonzalez',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e879ef7a1ca99f58b89424'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e87d477a1ca99f58b89426'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e90fe34cdf64a3f86b9631'),
#   'nombre': 'William ',
#   'apellido': 'Cañas',
#   'edad': 56,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66ea3e41d717140caee638da'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ea3fdc57a45de96889a9d7'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66eca5e4486fb3df625689a9'),
#   'nombre': 'Albeto',
#   'apellido': 'Giraldo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecc79b18fce9c9574d4ce0'),
#   'nombre': 'Alberto',
#   'Giraldo': 'Caicedo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecf7279885b254cad9ecf5'),
#   'nombre': 'Andres',
#   'apellido': 'Borrero',
#   'edad': 27,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ed62ce8ad24b7c88fb5eb9'),
#   'nombre': 'Alejandro',
#   'apellido': 'Patiño',
#   'edad': 40,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb741c48c1d4299d20f8'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eee1995986e7f02ec94af7'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f0b9a6a744512cc0a45daf'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f231784638df56c36a4151'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f23ba3f759e5d8a95cd01c'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f83a9b808f0957a483ada8'),
#   'nombre': 'Yesid',
#   'apellido': 'Castelblanco',
#   'edad': 35,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67d1e227cbb3a2825b2bdb67'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 43,
#   'estatura': 1.6},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb68'),
#   'nombre': 'Luis',
#   'apellido': 'Ruiz',
#   'edad': 48,
#   'estatura': '1.70'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb69'),
#   'nombre': 'Leonor',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb6a'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67db4239cdce94eb28048f1a'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db5025cef8af8508084a3e'),
#   'nombre': 'Ricardo',
#   'apellido': 'Chicangana',
#   'edad': 44,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e020fcf9ac118b7ebeb9ba'),
#   'nombre': 'Fabian',
#   'apellido': 'Ortiz',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e03ba5a7fe6c5cbaa78c87'),
#   'nombre': 'Laura',
#   'apellido': 'Chaparro',
#   'edad': 24,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e406cf06601db2266ef129'),
#   'nombre': 'Ivan',
#   'apellido': 'Mora',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5ddd4f2df8b9d1485408a'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5deb4f2df8b9d1485408b'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e806a64c7ac3f94970398e'),
#   'nombre': 'sebastian',
#   'apellido': 'bonilla',
#   'edad': 30,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e980c1262e6b8bc6cd7c34'),
#   'nombre': 'Josué',
#   'apellido': 'Cobaleda',
#   'edad': 31,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9bc55b78b2d7303ca75dc'),
#   'nombre': 'Jhonattan Reales',
#   'apellido': 'Reales',
#   'edad': 26,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9e8f6b1aa8f907d316010'),
#   'nombre': 'Juan',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67fdc82cc5881dce4b10f52f'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67fdc84ec5881dce4b10f530'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado Angulo',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d1783e02f974d8ff0918ed'),
#   'nombre': 'Deibi',
#   'apellido': 'Bastidas',
#   'edad': 43,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d2d16dfe299cff65aefb01'),
#   'nombre': 'Darwin',
#   'apellido': 'Lenis',
#   'edad': 21,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d3e081d6bc5259fd2712ce'),
#   'nombre': 'Diana',
#   'apellido': 'López',
#   'edad': 23,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4626b3a5685ae5c2475b2'),
#   'nombre': 'William Alberto',
#   'apellido': 'Suaza Losada',
#   'edad': 42,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('68d46a0ce8dc84be6f7d17ed'),
#   'nombre': 'Yenny',
#   'apellido': 'Villarreal',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d486f1a3667c7041432055'),
#   'nombre': 'Carlos',
#   'apellido': 'Cepeda',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4916d4ed299576c35f9c7'),
#   'nombre': 'Yeny1',
#   'apellido': 'Villarreal2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492aa4ed299576c35f9ca'),
#   'nombre': 'Neny',
#   'apellido': 'cita',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492db4ed299576c35f9cb'),
#   'nombre': 'alexandra',
#   'apellido': 'suaza',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d494f04ed299576c35f9cd'),
#   'nombre': 'alexandra2',
#   'apellido': 'suaza2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d495f685a9ccca1468d68f'),
#   'nombre': 'Yenny3',
#   'apellido': 'Villarreal3',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d498614ed299576c35f9d0'),
#   'nombre': 'cristian',
#   'apellido': 'yepes',
#   'edad': 38,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d498954ed299576c35f9d1'),
#   'nombre': 'Cris',
#   'apellido': 'Yes',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4a101a9a01c1b4bcebea6'),
#   'nombre': 'Juanse',
#   'apellido': 'Orozco',
#   'edad': 35,
#   'estatura': 1.78},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d58c21872b0599fc341a63'),
#   'nombre': 'Ruben Dario',
#   'apellido': 'Sabogal Urbano',
#   'edad': 60,
#   'genero': 'masculino'}]

# %% [markdown]
# **Consulta con el operador OR**
#
# Mostrar los usuarios con nombre Mario o apellido Rojas

# %%
list(db.users.find({'$or':[{'nombre':'Mario'},{'apellido':'Rojas'}]}))
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f231784638df56c36a4151'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'}]

# %% [markdown]
# **Mostrar los generos distintos**

# %%
db.users.distinct('genero')
# Out:
# ['Femenino', 'Masculino', 'femenino', 'masculino']

# %% [markdown]
# **Consultas**
#
# Practica realizando las siguientes consultas

# %% [markdown]
# 1.   Consulte todos los documentos

# %%
list(db.users.find())
# Out:
# [{'_id': ObjectId('66b2535cc0bcf1bf786032ad'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 47,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66c69ca73756af26287fb69e'),
#   'nombre': 'Andres',
#   'apellido': 'Rodriguez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66c69e743756af26287fb69f'),
#   'nombre': 'Felipe',
#   'apellido': 'Perez'},
#  {'_id': ObjectId('66ca25ae617e63bd422fb742'),
#   'nombre': 'Danna',
#   'apellido': 'Espinosa',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ca26b1fe854902920261af'),
#   'nombre': 'Jonathan',
#   'apellido': 'Pacheco',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66cdf6b3cf781c0d50e9b5ae'),
#   'nombre': 'David',
#   'apellido': 'Orozco',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d0f266b65667b4a5a498bb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 28,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d0f279b65667b4a5a498bc'),
#   'nombre': 'Alexandra',
#   'apellido': 'Arenas',
#   'edad': 21,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66d3320c4e581d85d3624d2b'),
#   'nombre': 'Danny',
#   'apellido': 'Martinez',
#   'edad': 37,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66d93c1976cc429b75215303'),
#   'nombre': 'Carlos Alberto',
#   'apellido': 'Martinez Ramirez',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215304'),
#   'nombre': 'Maria Antonieta',
#   'apellido': 'De las Nieves',
#   'edad': 37,
#   'genero': 'Femenino'},
#  {'_id': ObjectId('66d93c2876cc429b75215305'),
#   'nombre': 'Ramón',
#   'apellido': 'Villagra',
#   'edad': 65,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66d93c2876cc429b75215306'),
#   'nombre': 'Michael',
#   'apellido': 'Jackson',
#   'edad': 52,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66df57c44e564b16d03c8297'),
#   'nombre': 'Cristian David',
#   'apellido': 'Gonzalez',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e879ef7a1ca99f58b89424'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e87d477a1ca99f58b89426'),
#   'nombre': 'Sebastian',
#   'apellido': 'Murillas',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66e90fe34cdf64a3f86b9631'),
#   'nombre': 'William ',
#   'apellido': 'Cañas',
#   'edad': 56,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66ea3e41d717140caee638da'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ea3fdc57a45de96889a9d7'),
#   'nombre': 'Carlos',
#   'apellido': 'Velez',
#   'edad': 25,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66eca5e4486fb3df625689a9'),
#   'nombre': 'Albeto',
#   'apellido': 'Giraldo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecc79b18fce9c9574d4ce0'),
#   'nombre': 'Alberto',
#   'Giraldo': 'Caicedo',
#   'edad': 49,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ecf7279885b254cad9ecf5'),
#   'nombre': 'Andres',
#   'apellido': 'Borrero',
#   'edad': 27,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66ed62898ad24b7c88fb5eb8'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66ed62ce8ad24b7c88fb5eb9'),
#   'nombre': 'Alejandro',
#   'apellido': 'Patiño',
#   'edad': 40,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('66edec6ae71c965a8531f6b0'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb631c48c1d4299d20f7'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eedb741c48c1d4299d20f8'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66eee1995986e7f02ec94af7'),
#   'nombre': 'Joshua',
#   'apellido': 'Triana',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f0931a50efbcf41a5136b2')},
#  {'_id': ObjectId('66f0b9a6a744512cc0a45daf'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f231784638df56c36a4151'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('66f23ba3f759e5d8a95cd01c'),
#   'nombre': 'Jhonatan',
#   'apellido': 'Estrada',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('66f83a9b808f0957a483ada8'),
#   'nombre': 'Yesid',
#   'apellido': 'Castelblanco',
#   'edad': 35,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67d1e227cbb3a2825b2bdb67'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 43,
#   'estatura': 1.6},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb68'),
#   'nombre': 'Luis',
#   'apellido': 'Ruiz',
#   'edad': 48,
#   'estatura': '1.70'},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb69'),
#   'nombre': 'Leonor',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('67d1e359cbb3a2825b2bdb6a'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('67d8db390f07d2f1d1bc79a1'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67db4005cdce94eb28048f13')},
#  {'_id': ObjectId('67db40c4cdce94eb28048f15')},
#  {'_id': ObjectId('67db4239cdce94eb28048f1a'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db426dcdce94eb28048f1b'),
#   'nombre': 'Andres',
#   'apellido': 'Meneses',
#   'edad': 'treinta y tres',
#   'genero': 'masculino'},
#  {'_id': ObjectId('67db5025cef8af8508084a3e'),
#   'nombre': 'Ricardo',
#   'apellido': 'Chicangana',
#   'edad': 44,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67db604b16f8c4a3dfbe95a4'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e020fcf9ac118b7ebeb9ba'),
#   'nombre': 'Fabian',
#   'apellido': 'Ortiz',
#   'edad': 33,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e03ba5a7fe6c5cbaa78c87'),
#   'nombre': 'Laura',
#   'apellido': 'Chaparro',
#   'edad': 24,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e406cf06601db2266ef129'),
#   'nombre': 'Ivan',
#   'apellido': 'Mora',
#   'edad': 45,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5dceb5ddd75422576561b'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5dd0c5ddd75422576561c'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e5ddd4f2df8b9d1485408a'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5deb4f2df8b9d1485408b'),
#   'nombre': 'Erik',
#   'apellido': 'Vergara',
#   'edad': 25,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67e5e429d08c653e5c3ea696'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e7ff010476498f6d784fbb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e806a64c7ac3f94970398e'),
#   'nombre': 'sebastian',
#   'apellido': 'bonilla',
#   'edad': 30,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e97828262e6b8bc6cd7c33'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e980c1262e6b8bc6cd7c34'),
#   'nombre': 'Josué',
#   'apellido': 'Cobaleda',
#   'edad': 31,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e99e0fd5abdb57e634ff7f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9bc55b78b2d7303ca75dc'),
#   'nombre': 'Jhonattan Reales',
#   'apellido': 'Reales',
#   'edad': 26,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67e9e8c6b1aa8f907d31600f'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67e9e8f6b1aa8f907d316010'),
#   'nombre': 'Juan',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('67fdc7cbc5881dce4b10f52e'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('67fdc82cc5881dce4b10f52f'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67fdc84ec5881dce4b10f530'),
#   'nombre': 'Juan Manuel',
#   'apellido': 'Hurtado Angulo',
#   'edad': 50,
#   'genero': 'masculino'},
#  {'_id': ObjectId('67ff453279a1cb75bce3dfd9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d16c537d604af1453912e2'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d1783e02f974d8ff0918ed'),
#   'nombre': 'Deibi',
#   'apellido': 'Bastidas',
#   'edad': 43,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d2d148fe299cff65aefb00'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d2d16dfe299cff65aefb01'),
#   'nombre': 'Darwin',
#   'apellido': 'Lenis',
#   'edad': 21,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d3e081d6bc5259fd2712ce'),
#   'nombre': 'Diana',
#   'apellido': 'López',
#   'edad': 23,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d41394dc3254cb2b1facf9'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d42ee248396e781fd2f2e6'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42ef848396e781fd2f2e7'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f5e48396e781fd2f2e8'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42f7048396e781fd2f2e9'),
#   'nombre': 'Eren',
#   'apellido': 'Jaeger',
#   'edad': 19,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d42fc448396e781fd2f2ea'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4309e48396e781fd2f2eb'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d4626b3a5685ae5c2475b2'),
#   'nombre': 'William Alberto',
#   'apellido': 'Suaza Losada',
#   'edad': 42,
#   'genero': 'Masculino'},
#  {'_id': ObjectId('68d46a0ce8dc84be6f7d17ed'),
#   'nombre': 'Yenny',
#   'apellido': 'Villarreal',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d486f1a3667c7041432055'),
#   'nombre': 'Carlos',
#   'apellido': 'Cepeda',
#   'edad': 35,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4916d4ed299576c35f9c7'),
#   'nombre': 'Yeny1',
#   'apellido': 'Villarreal2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492aa4ed299576c35f9ca'),
#   'nombre': 'Neny',
#   'apellido': 'cita',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d492db4ed299576c35f9cb'),
#   'nombre': 'alexandra',
#   'apellido': 'suaza',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d494f04ed299576c35f9cd'),
#   'nombre': 'alexandra2',
#   'apellido': 'suaza2',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d495f685a9ccca1468d68f'),
#   'nombre': 'Yenny3',
#   'apellido': 'Villarreal3',
#   'edad': 36,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d498614ed299576c35f9d0'),
#   'nombre': 'cristian',
#   'apellido': 'yepes',
#   'edad': 38,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d498954ed299576c35f9d1'),
#   'nombre': 'Cris',
#   'apellido': 'Yes',
#   'edad': 36,
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d4a101a9a01c1b4bcebea6'),
#   'nombre': 'Juanse',
#   'apellido': 'Orozco',
#   'edad': 35,
#   'estatura': 1.78},
#  {'_id': ObjectId('68d51bc5831e53f6213fefbd'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'edad': 35,
#   'genero': 'femenino'},
#  {'_id': ObjectId('68d52b2777e8775ae8576fbc'),
#   'nombre': 'Carlos',
#   'apellido': 'García',
#   'edad': '35',
#   'genero': 'masculino'},
#  {'_id': ObjectId('68d58c21872b0599fc341a63'),
#   'nombre': 'Ruben Dario',
#   'apellido': 'Sabogal Urbano',
#   'edad': 60,
#   'genero': 'masculino'}]

# %% [markdown]
# 2.   Muestre los nombres, apellidos de todos los usuarios, sin mostrar el campo *_id*

# %%
# Out:
# [{'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Andres', 'apellido': 'Rodriguez'},
#  {'nombre': 'Felipe', 'apellido': 'Perez'},
#  {'nombre': 'Danna', 'apellido': 'Espinosa'},
#  {'nombre': 'Jonathan', 'apellido': 'Pacheco'},
#  {'nombre': 'David', 'apellido': 'Orozco'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Alexandra', 'apellido': 'Arenas'},
#  {'nombre': 'Danny', 'apellido': 'Martinez'},
#  {'nombre': 'Carlos Alberto', 'apellido': 'Martinez Ramirez'},
#  {'nombre': 'Maria Antonieta', 'apellido': 'De las Nieves'},
#  {'nombre': 'Ramón', 'apellido': 'Villagra'},
#  {'nombre': 'Michael', 'apellido': 'Jackson'},
#  {'nombre': 'Cristian David', 'apellido': 'Gonzalez'},
#  {'nombre': 'Sebastian', 'apellido': 'Murillas'},
#  {'nombre': 'Sebastian', 'apellido': 'Murillas'},
#  {'nombre': 'William ', 'apellido': 'Cañas'},
#  {'nombre': 'Carlos', 'apellido': 'Velez'},
#  {'nombre': 'Carlos', 'apellido': 'Velez'},
#  {'nombre': 'Albeto', 'apellido': 'Giraldo'},
#  {'nombre': 'Alberto'},
#  {'nombre': 'Andres', 'apellido': 'Borrero'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Alejandro', 'apellido': 'Patiño'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Joshua', 'apellido': 'Triana'},
#  {'nombre': 'Joshua', 'apellido': 'Triana'},
#  {},
#  {'nombre': 'Jhonatan', 'apellido': 'Estrada'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Jhonatan', 'apellido': 'Estrada'},
#  {'nombre': 'Yesid', 'apellido': 'Castelblanco'},
#  {'nombre': 'Maria', 'apellido': 'Andrade'},
#  {'nombre': 'Luis', 'apellido': 'Ruiz'},
#  {'nombre': 'Leonor', 'apellido': 'Restrepo'},
#  {'nombre': 'Leonardo', 'apellido': 'Jurado'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {},
#  {},
#  {'nombre': 'Andres', 'apellido': 'Meneses'},
#  {'nombre': 'Andres', 'apellido': 'Meneses'},
#  {'nombre': 'Ricardo', 'apellido': 'Chicangana'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Fabian', 'apellido': 'Ortiz'},
#  {'nombre': 'Laura', 'apellido': 'Chaparro'},
#  {'nombre': 'Ivan', 'apellido': 'Mora'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Erik', 'apellido': 'Vergara'},
#  {'nombre': 'Erik', 'apellido': 'Vergara'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'sebastian', 'apellido': 'bonilla'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Josué', 'apellido': 'Cobaleda'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Jhonattan Reales', 'apellido': 'Reales'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Juan', 'apellido': 'Hurtado'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Juan Manuel', 'apellido': 'Hurtado'},
#  {'nombre': 'Juan Manuel', 'apellido': 'Hurtado Angulo'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Deibi', 'apellido': 'Bastidas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Darwin', 'apellido': 'Lenis'},
#  {'nombre': 'Diana', 'apellido': 'López'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'William Alberto', 'apellido': 'Suaza Losada'},
#  {'nombre': 'Yenny', 'apellido': 'Villarreal'},
#  {'nombre': 'Carlos', 'apellido': 'Cepeda'},
#  {'nombre': 'Yeny1', 'apellido': 'Villarreal2'},
#  {'nombre': 'Neny', 'apellido': 'cita'},
#  {'nombre': 'alexandra', 'apellido': 'suaza'},
#  {'nombre': 'alexandra2', 'apellido': 'suaza2'},
#  {'nombre': 'Yenny3', 'apellido': 'Villarreal3'},
#  {'nombre': 'cristian', 'apellido': 'yepes'},
#  {'nombre': 'Cris', 'apellido': 'Yes'},
#  {'nombre': 'Juanse', 'apellido': 'Orozco'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Carlos', 'apellido': 'García'},
#  {'nombre': 'Ruben Dario', 'apellido': 'Sabogal Urbano'}]

# %% [markdown]
# 3.   Muestre los nombres y apellidos de los usuarios mayores de 18 años

# %%
list(db.users.find({'edad': {'$gt': 18}}, {'nombre': 1, 'apellido': 1, '_id': 0}))
# Out:
# [{'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Andres', 'apellido': 'Rodriguez'},
#  {'nombre': 'Danna', 'apellido': 'Espinosa'},
#  {'nombre': 'Jonathan', 'apellido': 'Pacheco'},
#  {'nombre': 'David', 'apellido': 'Orozco'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Alexandra', 'apellido': 'Arenas'},
#  {'nombre': 'Danny', 'apellido': 'Martinez'},
#  {'nombre': 'Carlos Alberto', 'apellido': 'Martinez Ramirez'},
#  {'nombre': 'Maria Antonieta', 'apellido': 'De las Nieves'},
#  {'nombre': 'Ramón', 'apellido': 'Villagra'},
#  {'nombre': 'Michael', 'apellido': 'Jackson'},
#  {'nombre': 'Cristian David', 'apellido': 'Gonzalez'},
#  {'nombre': 'Sebastian', 'apellido': 'Murillas'},
#  {'nombre': 'Sebastian', 'apellido': 'Murillas'},
#  {'nombre': 'William ', 'apellido': 'Cañas'},
#  {'nombre': 'Carlos', 'apellido': 'Velez'},
#  {'nombre': 'Carlos', 'apellido': 'Velez'},
#  {'nombre': 'Albeto', 'apellido': 'Giraldo'},
#  {'nombre': 'Alberto'},
#  {'nombre': 'Andres', 'apellido': 'Borrero'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Alejandro', 'apellido': 'Patiño'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Joshua', 'apellido': 'Triana'},
#  {'nombre': 'Joshua', 'apellido': 'Triana'},
#  {'nombre': 'Jhonatan', 'apellido': 'Estrada'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Jhonatan', 'apellido': 'Estrada'},
#  {'nombre': 'Yesid', 'apellido': 'Castelblanco'},
#  {'nombre': 'Maria', 'apellido': 'Andrade'},
#  {'nombre': 'Luis', 'apellido': 'Ruiz'},
#  {'nombre': 'Leonor', 'apellido': 'Restrepo'},
#  {'nombre': 'Leonardo', 'apellido': 'Jurado'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Andres', 'apellido': 'Meneses'},
#  {'nombre': 'Ricardo', 'apellido': 'Chicangana'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Fabian', 'apellido': 'Ortiz'},
#  {'nombre': 'Laura', 'apellido': 'Chaparro'},
#  {'nombre': 'Ivan', 'apellido': 'Mora'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Erik', 'apellido': 'Vergara'},
#  {'nombre': 'Erik', 'apellido': 'Vergara'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'sebastian', 'apellido': 'bonilla'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Josué', 'apellido': 'Cobaleda'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Jhonattan Reales', 'apellido': 'Reales'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Juan', 'apellido': 'Hurtado'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Juan Manuel', 'apellido': 'Hurtado'},
#  {'nombre': 'Juan Manuel', 'apellido': 'Hurtado Angulo'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Deibi', 'apellido': 'Bastidas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Darwin', 'apellido': 'Lenis'},
#  {'nombre': 'Diana', 'apellido': 'López'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Eren', 'apellido': 'Jaeger'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'William Alberto', 'apellido': 'Suaza Losada'},
#  {'nombre': 'Yenny', 'apellido': 'Villarreal'},
#  {'nombre': 'Carlos', 'apellido': 'Cepeda'},
#  {'nombre': 'Yeny1', 'apellido': 'Villarreal2'},
#  {'nombre': 'Neny', 'apellido': 'cita'},
#  {'nombre': 'alexandra', 'apellido': 'suaza'},
#  {'nombre': 'alexandra2', 'apellido': 'suaza2'},
#  {'nombre': 'Yenny3', 'apellido': 'Villarreal3'},
#  {'nombre': 'cristian', 'apellido': 'yepes'},
#  {'nombre': 'Cris', 'apellido': 'Yes'},
#  {'nombre': 'Juanse', 'apellido': 'Orozco'},
#  {'nombre': 'Monica', 'apellido': 'Rojas'},
#  {'nombre': 'Ruben Dario', 'apellido': 'Sabogal Urbano'}]
